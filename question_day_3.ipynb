# %% [markdown]
# # How to practice in this file
# You can use this file in two ways:
# 1. **Using VS Code**:
#    - Download this file
#    - Open this file in Visual Studio Code.
#    - Install python and the Jupyter extension if you haven't already.
#    - Select the kernel using the top right corner dropdown.
#    - Create a code cell by clicking the `+ Code` button above the the line.
#    - Run the code cell by clicking the play button on the left side of the cell.
# 2. **Using Google Colab**:
#    - Download this file.
#    - Upload the notebook file to your Google Drive.
#    - Open the file with Google Colaboratory (use open with and then select connected app and install google colaboratory to use).
#    - Add code cells by clicking the `+ Code` button. Solve the exercises in the code cells.
#    - Run the code cell by clicking the play button on the left side of the cell.

# %% [markdown]
# # Day 3 — Conditionals, Loops & Nested Logic
#
# This notebook contains the 35 practice problem statements (questions only). Use `solution_day_3.ipynb` for the solutions.
#
# Focus Topics: Nested loops and conditional problems, patterns and formatted outputs, decision logic and recursion basics.

# %% [markdown]
# ---
#
# ## Problem 1 — Print Pascal’s Triangle
#
# Problem: Given N, print the first N rows of Pascal’s Triangle.
#
# Input:
# N (integer)
#
# Output:
# N lines, each with space-separated integers.
#
# Sample:
# Input: 3
# Output:
# 1
# 1 1
# 1 2 1

# %% [markdown]
# ---
#
# ## Problem 2 — Generate Fibonacci series up to N
#
# Problem: Generate Fibonacci series up to the Nth term.
#
# Input:
# N (integer)
#
# Output:
# Space-separated Fibonacci numbers.
#
# Sample:
# Input: 5
# Output: 0 1 1 2 3

# %% [markdown]
# ---
#
# ## Problem 3 — Factorial using recursion
#
# Problem: Compute N! using recursion.
#
# Input:
# N (integer)
#
# Output:
# N!
#
# Sample:
# Input: 5
# Output: 120

# %% [markdown]
# ---
#
# ## Problem 4 — Check Armstrong number
#
# Problem: Check if N is an Armstrong number.
#
# Input:
# N (integer)
#
# Output:
# 'Yes' or 'No'
#
# Sample:
# Input: 153
# Output: Yes

# %% [markdown]
# ---
#
# ## Problem 5 — Check Perfect number
#
# Problem: Check if N is a perfect number.
#
# Input:
# N (integer)
#
# Output:
# 'Yes' or 'No'
#
# Sample:
# Input: 6
# Output: Yes

# %% [markdown]
# ---
#
# ## Problem 6 — Print star pyramid
#
# Problem: Print a pyramid of stars with N rows.
#
# Input:
# N
#
# Output:
# Pyramid pattern
#
# Sample:
# N=3
#   *
#  ***
# *****

# %% [markdown]
# ---
#
# ## Problem 7 — Print number pyramid
#
# Problem: Print a pyramid of numbers.
#
# Input:
# N
#
# Output:
# Number pyramid
#
# Sample:
# N=3
#   1
#  123
# 12345

# %% [markdown]
# ---
#
# ## Problem 8 — Sum of series 1 to N
#
# Problem: Sum from 1 to N.
#
# Input:
# N
#
# Output:
# Sum
#
# Sample:
# Input: 5
# Output: 15

# %% [markdown]
# ---
#
# ## Problem 9 — Product of series 1 to N
#
# Problem: Product from 1 to N.
#
# Input:
# N
#
# Output:
# Product
#
# Sample:
# Input: 5
# Output: 120

# %% [markdown]
# ---
#
# ## Problem 10 — Check prime
#
# Problem: Check if N is prime.
#
# Input:
# N
#
# Output:
# 'Prime' or 'Not Prime'
#
# Sample:
# Input: 7
# Output: Prime

# %% [markdown]
# ---
#
# ## Problem 11 — Print multiplication table
#
# Problem: Print multiplication table for N up to 10.
#
# Input:
# N
#
# Output:
# Table
#
# Sample:
# Input: 2
# Output:
# 2 x 1 = 2
# ...
# 2 x 10 = 20

# %% [markdown]
# ---
#
# ## Problem 12 — Print hollow square
#
# Problem: Print hollow square of size N.
#
# Input:
# N
#
# Output:
# Hollow square
#
# Sample:
# N=3
# ***
# * *
# ***

# %% [markdown]
# ---
#
# ## Problem 13 — Print diamond pattern
#
# Problem: Print diamond of stars.
#
# Input:
# N
#
# Output:
# Diamond
#
# Sample:
# N=3
#   *
#  ***
# *****
#  ***
#   *

# %% [markdown]
# ---
#
# ## Problem 14 — GCD recursive
#
# Problem: Compute GCD using recursion.
#
# Input:
# A B
#
# Output:
# GCD
#
# Sample:
# Input: 12 18
# Output: 6

# %% [markdown]
# ---
#
# ## Problem 15 — LCM
#
# Problem: Compute LCM.
#
# Input:
# A B
#
# Output:
# LCM
#
# Sample:
# Input: 4 6
# Output: 12

# %% [markdown]
# ---
#
# ## Problem 16 — Tower of Hanoi
#
# Problem: Solve Tower of Hanoi for N disks.
#
# Input:
# N
#
# Output:
# Moves
#
# Sample:
# N=2
# Move disk 1 from A to B
# Move disk 2 from A to C
# Move disk 1 from B to C

# %% [markdown]
# ---
#
# ## Problem 17 — Binary search recursive
#
# Problem: Binary search in sorted list.
#
# Input:
# List and target
#
# Output:
# Index or -1
#
# Sample:
# List: [1,2,3,4,5], target: 3
# Output: 2

# %% [markdown]
# ---
#
# ## Problem 18 — Sum of digits recursive
#
# Problem: Sum digits recursively.
#
# Input:
# N
#
# Output:
# Sum
#
# Sample:
# Input: 123
# Output: 6

# %% [markdown]
# ---
#
# ## Problem 19 — Reverse string recursive
#
# Problem: Reverse string recursively.
#
# Input:
# S
#
# Output:
# Reversed S
#
# Sample:
# Input: hello
# Output: olleh

# %% [markdown]
# ---
#
# ## Problem 20 — Power recursive
#
# Problem: Compute a^b recursively.
#
# Input:
# A B
#
# Output:
# A^B
#
# Sample:
# Input: 2 3
# Output: 8

# %% [markdown]
# ---
#
# ## Problem 21 — Print permutations
#
# Problem: Print all permutations of string.
#
# Input:
# S
#
# Output:
# Permutations
#
# Sample:
# Input: ab
# Output:
# ab
# ba

# %% [markdown]
# ---
#
# ## Problem 22 — Check leap year
#
# Problem: Check if year is leap.
#
# Input:
# Year
#
# Output:
# 'Leap' or 'Not Leap'
#
# Sample:
# Input: 2020
# Output: Leap

# %% [markdown]
# ---
#
# ## Problem 23 — Print primes up to N
#
# Problem: Print all primes up to N.
#
# Input:
# N
#
# Output:
# Primes
#
# Sample:
# Input: 10
# Output: 2 3 5 7

# %% [markdown]
# ---
#
# ## Problem 24 — Fibonacci triangle
#
# Problem: Print Fibonacci triangle.
#
# Input:
# N
#
# Output:
# Triangle
#
# Sample:
# N=3
# 1
# 1 1
# 1 1 2

# %% [markdown]
# ---
#
# ## Problem 25 — Floyd's triangle
#
# Problem: Print Floyd's triangle.
#
# Input:
# N
#
# Output:
# Triangle
#
# Sample:
# N=3
# 1
# 2 3
# 4 5 6

# %% [markdown]
# ---
#
# ## Problem 26 — Check palindrome recursive
#
# Problem: Check if string is palindrome recursively.
#
# Input:
# S
#
# Output:
# 'Yes' or 'No'
#
# Sample:
# Input: radar
# Output: Yes

# %% [markdown]
# ---
#
# ## Problem 27 — Merge sort recursive
#
# Problem: Sort list using merge sort.
#
# Input:
# List
#
# Output:
# Sorted list
#
# Sample:
# Input: [3,1,4,1,5]
# Output: [1,1,3,4,5]

# %% [markdown]
# ---
#
# ## Problem 28 — Quick sort recursive
#
# Problem: Sort list using quick sort.
#
# Input:
# List
#
# Output:
# Sorted list
#
# Sample:
# Input: [3,1,4,1,5]
# Output: [1,1,3,4,5]

# %% [markdown]
# ---
#
# ## Problem 29 — Print inverted pyramid
#
# Problem: Print inverted star pyramid.
#
# Input:
# N
#
# Output:
# Inverted pyramid
#
# Sample:
# N=3
# *****
#  ***
#   *

# %% [markdown]
# ---
#
# ## Problem 30 — Print right-angled triangle
#
# Problem: Print right-angled triangle of stars.
#
# Input:
# N
#
# Output:
# Triangle
#
# Sample:
# N=3
# *
# **
# ***

# %% [markdown]
# ---
#
# ## Problem 31 — Sum of cubes
#
# Problem: Sum of cubes from 1 to N.
#
# Input:
# N
#
# Output:
# Sum
#
# Sample:
# Input: 3
# Output: 36

# %% [markdown]
# ---
#
# ## Problem 32 — Product of primes
#
# Problem: Product of first N primes.
#
# Input:
# N
#
# Output:
# Product
#
# Sample:
# Input: 3
# Output: 30

# %% [markdown]
# ---
#
# ## Problem 33 — Tracing pseudocode
#
# Problem: Trace the given pseudocode and find output.
#
# Input:
# N
#
# Output:
# Output of code
#
# Sample:
# Assume some pseudocode, but since text, say for N=3, output 6

# %% [markdown]
# ---
#
# ## Problem 34 — Nested loop sum
#
# Problem: Sum using nested loops.
#
# Input:
# N
#
# Output:
# Sum
#
# Sample:
# Input: 3
# Output: 36

# %% [markdown]
# ---
#
# ## Problem 35 — Recursive count
#
# Problem: Count something recursively.
#
# Input:
# N
#
# Output:
# Count
#
# Sample:
# Input: 5
# Output: 15

# %% [markdown]
# ---
#
# Built by Zaid Kamil with 💖 at MBU
# [Connect me on LinkedIn](https://www.linkedin.com/in/zaidbinkamil/)
